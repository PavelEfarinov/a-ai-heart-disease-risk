# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heart_data.csv').drop(columns=['index', 'id'])
df
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# ...

# %%
(df['age'] / 365).describe()
# Out:
# count    70000.000000
# mean        53.339358
# std          6.759594
# min         29.583562
# 25%         48.394521
# 50%         53.980822
# 75%         58.430137
# max         64.967123
# Name: age, dtype: float64

# %%
corr = df.corr()
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
df.hist(ax = ax)
# Out:
# C:\Program Files\Python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'gender'}>,
#         <AxesSubplot:title={'center':'height'}>],
#        [<AxesSubplot:title={'center':'weight'}>,
#         <AxesSubplot:title={'center':'ap_hi'}>,
#         <AxesSubplot:title={'center':'ap_lo'}>],
#        [<AxesSubplot:title={'center':'cholesterol'}>,
#         <AxesSubplot:title={'center':'gluc'}>,
#         <AxesSubplot:title={'center':'smoke'}>],
#        [<AxesSubplot:title={'center':'alco'}>,
#         <AxesSubplot:title={'center':'active'}>,
#         <AxesSubplot:title={'center':'cardio'}>]], dtype=object)

# %%
df.isna().sum()
# Out:
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df[df['ap_hi'] > 250]
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 1876   15116       1     160    60.0    902     60            1     1      0
# 2014   22712       2     167    59.0    906      0            1     1      0
# 4817   14425       1     168    63.0    909     60            2     1      0
# 7763   21032       1     175    80.0  11500     90            1     1      0
# 8915   18870       1     164    75.0   1420     80            2     1      0
# 9557   22659       1     155    87.0    701    110            1     1      0
# 13895  15996       1     168    72.0   1500     80            1     1      0
# 17713  22398       2     163    50.0    907     70            3     3      0
# 23867  16131       1     161    92.0    906      0            2     1      0
# 25464  15835       2     169    75.0  14020     80            2     1      0
# 25519  21361       1     169    71.0  14020     80            3     3      0
# ...

# %%
df = df[(df['ap_hi'] < 300) & (df['ap_hi'] > 0)]

# %%
df = df[(df['ap_lo'] < 300) & (df['ap_lo'] > 0)]
df
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# ...

# %%
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
df.hist(ax = ax)
# Out:
# C:\Program Files\Python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'gender'}>,
#         <AxesSubplot:title={'center':'height'}>],
#        [<AxesSubplot:title={'center':'weight'}>,
#         <AxesSubplot:title={'center':'ap_hi'}>,
#         <AxesSubplot:title={'center':'ap_lo'}>],
#        [<AxesSubplot:title={'center':'cholesterol'}>,
#         <AxesSubplot:title={'center':'gluc'}>,
#         <AxesSubplot:title={'center':'smoke'}>],
#        [<AxesSubplot:title={'center':'alco'}>,
#         <AxesSubplot:title={'center':'active'}>,
#         <AxesSubplot:title={'center':'cardio'}>]], dtype=object)

# %%
df.height.describe()
# Out:
# count    68985.000000
# mean       164.359672
# std          8.204273
# min         55.000000
# 25%        159.000000
# 50%        165.000000
# 75%        170.000000
# max        250.000000
# Name: height, dtype: float64

# %%
df['years'] = (df['age'] / 365).astype(int)

# %%
df[(df.height > 210) | (df.height < 90)]
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 224    21800       2      76    55.0    120     80            1     1      0
# 6486   21220       1     250    86.0    140    100            3     1      0
# 7598   14661       2      70    72.0    120      8            1     1      0
# 12770  19594       1      75   168.0    120     80            1     1      1
# 13265  22456       2      71    68.0    120     80            3     1      0
# 14323  22005       1      67    57.0    120     90            1     1      0
# 15167  15812       1      70    68.0    120     80            1     1      0
# 16699  19680       2      74    98.0    140     90            1     1      0
# 22542  14538       1      68    65.0    100     60            1     1      0
# 22723  23386       1      55    81.0    130     90            1     1      0
# 23913  19074       1      81   156.0    140     90            1     1      0
# ...

# %%
df = df[(df.height < 210) & (df.height > 90)]

# %%
fig = plt.figure(figsize = (15,15))
ax = fig.gca()
df.hist(ax = ax)
# Out:
# C:\Program Files\Python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'gender'}>,
#         <AxesSubplot:title={'center':'height'}>,
#         <AxesSubplot:title={'center':'weight'}>],
#        [<AxesSubplot:title={'center':'ap_hi'}>,
#         <AxesSubplot:title={'center':'ap_lo'}>,
#         <AxesSubplot:title={'center':'cholesterol'}>,
#         <AxesSubplot:title={'center':'gluc'}>],
#        [<AxesSubplot:title={'center':'smoke'}>,
#         <AxesSubplot:title={'center':'alco'}>,
#         <AxesSubplot:title={'center':'active'}>,
#         <AxesSubplot:title={'center':'cardio'}>],
#        [<AxesSubplot:title={'center':'years'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
corr = df.corr()
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df[['ap_hi', 'ap_lo']])

# %%
df
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio  years
# ...

# %%
X = df.drop(columns=['cardio', 'years'])
y = df.cardio

# %%
df.to_csv('heart_data_after_eda.csv')

# %%
from sklearn.decomposition import PCA 
from sklearn.manifold import MDS, TSNE

# %%
pca = TSNE(n_components=2).fit(X)
# Out:
# C:\Program Files\Python37\lib\site-packages\sklearn\manifold\_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# C:\Program Files\Python37\lib\site-packages\sklearn\manifold\_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
X_pc = pca.fit_transform(X)
# Out:
# C:\Program Files\Python37\lib\site-packages\sklearn\manifold\_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# C:\Program Files\Python37\lib\site-packages\sklearn\manifold\_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
X_pc.shape
# Out:
# (68960, 2)

# %%
X_pc = pd.DataFrame(data=X_pc, columns=[f'pc_{i}' for i in range(X_pc.shape[1])])

# %%
X_pc
# Out:
#             pc_0       pc_1
# 0      37.537815   5.710175
# 1      39.706413  35.075054
# 2      42.466496 -41.626064
# 3       3.353372 -22.999573
# 4     -13.117699 -18.241928
# ...          ...        ...
# 68955  13.601841 -19.906200
# 68956 -47.972633  -4.100828
# 68957  23.321453 -15.753211
# 68958 -52.269241 -30.725327
# 68959  41.296455 -10.724976
#
# [68960 rows x 2 columns]

# %%
X_pc['cardio'] = y

# %%
sns.scatterplot(data=X_pc, x='pc_0', y='pc_1', hue='cardio')
# Out:
# <AxesSubplot:xlabel='pc_0', ylabel='pc_1'>
